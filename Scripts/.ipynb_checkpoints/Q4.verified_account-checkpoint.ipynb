# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-J364ET4:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
import tweepy as tw

# %%
#sc.stop()

# %%
consumer_key = 'H8J4lTPwHny8qt41OOxLFwNHH'
consumer_secret = 'KNTd6Kida34CBydCJYGm5leKBChBN86sTlMpkFZ6bkfkWAjaYb'
access_token = '3105826550-F4YMOB6ZljoceFpW2WTJctwxAFH757cEy6QwNXD'
access_secret = 'JJaTqeVLPqma5OtYsDwjTldEP8S8qqiRz4VcTmXGf1dwZ'

# %%
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api= tw.API(auth,wait_on_rate_limit =True)

# %%
search_words = "#olympic"
date_since = "2021-08-07"

# %%
tweets = tw.Cursor(api.search,q=search_words,lang="en",since=date_since).items(200)
#tweets = tw.Cursor(api.search, lang="en",since=date_since).items(20)
[tweet.text for tweet in tweets]
# Out:
# ['RT @16Sreejesh: Yeah ….. it’s taste salty, \n\nYeah …. I remember, it’s my sweat 😓 from last 21 years 🙏\n\n#medalist #olympic #games #olympicga…',
#  'RT @BangaloreTimes1: #Exclusive: On #IndependenceDay, #Olympic #gold medalist &amp; soldier @Neeraj_chopra1 talks about the discipline of the #…',
#  'RT @WomensRightsTW: What does short hair do with #feminist?\n\nSouth Korean gold medal-winning #archer, An San’s short haircut has attracted…',
#  "Can Neeraj Chopra's Olympic gold medal attract Bollywood towards athletics?\n#NeerajChopra #Olympic #Bollywood… https://t.co/S1JxN8FKdG",
#  "Can Neeraj Chopra's Olympic gold medal attract Bollywood towards athletics?\n#NeerajChopra #Olympic #Bollywood… https://t.co/Pms9WdrKM4",
#  'RT @BangaloreTimes1: #Exclusive: On #IndependenceDay, #Olympic #gold medalist &amp; soldier @Neeraj_chopra1 talks about the discipline of the #…',
#  'RT @PIBMumbai: Today, it is a matter of great pride for the country that whether it is education or sports or #Olympic medals - our daughte…',
#  'Had a great time meeting some #Olympic heros yesterday @TeamGB #IAmTeamGB #TeamGB https://t.co/wIP5L0sX6s',
#  'RT @Poorvika_Mobile: ஒரே Eventல ரெண்டு Gold | Emoji Show\n\nWatch now: https://t.co/reQPK3VEvP\n\n#PoorvikaMobilesTamil #PoorvikaMobiles #Poorv…',
#  'Congratulations to #Olympic medal winners, need to prepare for 70 medals now: @ArvindKejriwal',
#  'Congratulations to #Olympic medal winners, need to prepare for 70 medals now: @ArvindKejriwal',
#  'These #Olympic #Athletes Prove Success Is Ageless. "They show that age alone is not an insurmountable barrier to ex… https://t.co/sVIdkS67mR',
#  'RT @WomensRightsTW: “We’re so comfortable in our bodies,” she says. \n“There’s so many of us in this thing. You’re not alone.”\n\n#Tokyo2020 m…',
#  'RT @WomensRightsTW: “We’re so comfortable in our bodies,” she says. \n“There’s so many of us in this thing. You’re not alone.”\n\n#Tokyo2020 m…',
#  '#Celavi looked like #Olympic Champ Usain #Bolt! She wasn’t trying hard and still won easily😱❤️👍@KranjiBroadcast… https://t.co/77qtXnBo7C',
#  'RT @gotoutakesi00: @ESPRIMO7 @gerogeroR つ\nhttps://t.co/COqyLzmFue\n\n#終戦記念日\n\n#自民党は人災\n#OLYMPIC JAPAN CRAZY #Olympics\n#五輪終結 #自民党 #日本会議 #在特会 #大韓…',
#  "RT @ysjagan: Congratulations to @Neeraj_Chopra1, a serving soldier of Indian Army, who has made India proud by winning the nation's first-e…",
#
#  'RT @16Sreejesh: The smile define everything 💪🙏\n\n@Neeraj_chopra1 \n#history #gold #athletics #olympic #tokyo https://t.co/4rCZku4vny',
#  "RT @APPOLICE100: It's more than a medal, it is India's pride: Andhra Pradesh Police felicitate @Pvsindhu1 for bagging the Olympic #Bronze M…",
#  'RT @16Sreejesh: The smile define everything 💪🙏\n\n@Neeraj_chopra1 \n#history #gold #athletics #olympic #tokyo https://t.co/4rCZku4vny',
#  'Nation First, Always First!\n\nHappy Independence Day, India🧡🤍💚\n#IndependenceDay #IndependenceDay2021 #Independence… https://t.co/5y7YaWhRls',
#  'RT @tesfaldetsport: #Eritrea has completed its #Olympic Tokyo competition. #Swimming, #cycling and #athletics, what an impressive participa…',
#  'It feels good to be back on the ice! \nA big shout out to #ORDA and #NY state for investing in the future of sports… https://t.co/G0zH7lK3Z9',
#  'RT @HariomVhp: Golden moment for India 🇮🇳 Congrats ! #NeerajChopra for scripted history. My sandart at Puri beach in Odisha to celebrate fi…',
#  'RT @AndreaErcegovac: Congratulations - #Norway earned the bronze medal in #Olympic women’s handball. \n\nEspecially proud because @MartaTomac…',
#  "RT @peplosjeans: History has been created!!\n\n#neerajchopra of #ind takes #gold in the #athletics men's javelin final on his #Olympic debut!…",
#  '#OnThisDayInHistory in 2010 The inaugural edition of the Youth Olympic Games opened in Singapore for athletes betwe… https://t.co/9LDQUvOu3q']

# %%
new_search= search_words 
new_search
# Out:
# '#olympic'

# %%
tweets = tw.Cursor(api.search, q=new_search,lang="en",since=date_since).items(500)
users_details = [[tweet.user.screen_name,tweet.user.name,tweet.user.followers_count,tweet.user.verified]for tweet in tweets]
users_details
# Out:
# [['ShivA78904869', 'ShivA', 3, False],
#  ['Asifsnadaf2', 'ಆಸಿಫ್ ಎಸ್ ನದಾಫ್', 19, False],
#  ['Armani_or_Die', '👑Sporax•👑🇬🇭', 1127, False],
#  ['SocialNewsXYZ', 'SocialNews.XYZ', 475, False],
#  ['agk4444', '#Rajanna(G🌐pi AdusuⓂilli)', 350, False],
#  ['surajgowdafans1', 'surajgowdafansclub', 6, False],
#  ['maharashtra', 'Maharashtra🇮🇳', 3262, False],
#  ['MrBirdPhoto', 'Michael Bird', 203, False],
#  ['Priya65765668', 'Priya', 0, False],
#  ['mumbai_mitra', 'Daily MumbaiMitra', 76, False],
#  ['Dailyvruttmitra', 'Daily Vruttmitra', 297, False],
#  ['yagbebi', 'Yemmi Agbebi, MBA #BlackLivesMatter', 4853, False],
#  ['Babyolly4', '(･´з`･)', 1672, False],
#  ['syfrsyz', 'donut🇵🇸', 2384, False],
#  ['ElBronconator', 'J', 344, False],
#  ['ESPRIMO7', 'ESPRIMO＠ 江戸時代に戻ろう！\u3000Back to The Edo', 4738, False],
#  ['Amit_Raj_75', 'Amit Raj', 3, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['reubenbraham', 'Reuben Braham', 116, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['livjr75', 'Moot&Academic', 57, False],
#  ['HistriaBooks', 'Histria Books', 1085, False],
#  ['RaajakumaraAppu', 'ಸಚಿನ್ (ಅಪ್ಪು❤)', 310, False],
#  ['BangaloreTimes1', 'Bangalore Times', 159755, True],
#  ['AshrafulGolam', 'A.I.M.Golam Rabbany', 38, False],
#  ['m_1926ai', 'まいまい🌟 ランニング女子', 496, False],
#  ['Heavensangel67', 'Tania🕊', 13654, False],
#  ['Heavensangel67', 'Tania🕊', 13654, False],
#  ['Wind_at_Dusk', '夕暮れの風🎗️台湾队🏅️', 281, False],
#  ['vishalwatts92', 'VISHAL WATTS', 103, False],
#  ['IshikaY57405179', 'Ishika Yadav', 0, False],
#  ['JaykumarBhamare', 'jaykumar bhamare', 6, False],
#  ['mumaralid', 'Mian Umar Ali', 756, False],
#  ['SportslightMed_', 'Sportslight Media', 72, False],
#  ['LH', 'Luke Hutchison', 3057, False],
#  ['asghkel', 'Asghkel', 39, False],
#  ['JChaiyasothi', 'Jarkkrrapobb Chaiyasothi', 101, False],
#  ['BourneNatural', 'BourneNaturalBeauty', 5321, False],
#  ['lodha_siddhi', 'Siddhi Lodha', 13, False],
#  ['gearing_up_mind', 'Gearing Up Mind', 1, False],
#  ['ramcosmartbuild', 'Ramco SmartBuild', 1436, False],
#  ['Cryptolab888', 'Cryptolab888', 244, False],
#  ['IsmiMaulidyati', 'イスミ', 1574, False],
#  ['nrlsalihaa', 'ଘ˚𝒍𝒆𝒚𝒂˚✿', 54, False],
#  ['akemasyraf', 'Kemto', 580, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['okejuli', 'Eko Julianto', 277, False],
#  ['ridzuaaannn_', '🚀', 470, False],
#  ['apekshasandesh_', 'Apeksha Sandesh', 75, False],
#  ['HydTimes', 'Hyderabad Times', 57176, True],
#  ['So_ongDK', '𝘾𝙞𝙩𝙮 𝙇𝙞𝙜𝙝𝙩𝙨 Nobita', 296, False],
#  ['ieka93', 'HM', 5062, False],
#  ['MaCo_KaZ', 'KaZ@凛々', 731, False],
#  ['bwfmedia', 'BWF', 196780, True],
#  ['boysbyw', 'flandus', 3, False],
#  ['bhaswati10', 'Bhaswati Ghosh', 30645, False],
#  ['gonuguntlakish1', 'gonuguntla kishore', 7, False],
#  ['mathisanth', 'Mathisanth Kanagavel', 137, False],
#  ['jigyasu_aadmi', 'jigyasu aadmi', 31, False],
#  ['Cyient', 'Cyient', 19173, False],
#  ['dhavanyakalai', 'Dhavanyakalai', 0, False],
#  ['ranjitkumarTOI', 'Ranjit Kumar', 63, False],
#  ['s_subetha', 'Subetha S', 0, False],
#  ['rajuagn', 'RAJU MANDAL', 87, False],
#  ['Howl_India', 'Howl', 7, False],
#  ['Nameisrajanala', 'APGOTTHEBESTCM', 222, False],
#  ['yeshaa_always', 'India at 75 🇮🇳', 287, False],
#  ['DelhiTimesTweet', 'Delhi Times', 77812, True],
#  ['alleygator', 'Rodrigo Hunrichse', 1304, False],
#  ['doulthabad_ps', 'SHO_Doulthabad_PS', 371, False],
#  ['sooraj0222', 'SOORAJ0222', 5, False],
#  ['Chandon_Kala', 'Chandrakala P', 2368, False],
#  ['Jihad76381219', 'Jihad', 0, False],
#  ['are_akash', 'ARE AKASH SAI REDDY🔔', 391, False],
#  ['antony_naveen18', 'Antony Naveen', 45, False],
#  ['KUdhayavani', 'Kalamajiiraranjini Udhayavani', 34, False],
#  ['AmmarAlChalabi', 'Ammar Al-Chalabi', 3463, False],
#  ['nicephoebetiara', 'Blue Gardenia', 219, False],
#  ['ankushparihar32', 'Ankush Parihar', 3, False],
#  ['honey9834', 'Shashank Pandey 🇮🇳🕉️🚩🇮🇳🕉️🚩', 305, False],
#  ['PIBMumbai', 'PIB in Maharashtra 🇮🇳', 58955, True],
#  ['Jayasur41534375', 'Jayasurya', 6, False],
#  ['SuhaniSingh2021', 'Suhani Singh@2021', 1, False],
#  ['VoiceoftheBund', 'Voice of the Bund', 68, False],
#  ['subhanafnankha', 'Subhan Afnan khan', 53, False],
#  ['RomendraRajSin4', 'Romendra Raj Singh', 2, False],
#  ['shrishti_swaraj', 'Shrishti Swaraj', 28, False],
#  ['DanielA39318904', 'Daniel Aguayo', 15, False],
#  ['hkcd_HK', '香港商報', 66, False],
#  ['KasaniVeeresh', 'Veeresh Kasani', 573, False],
#  ['super_gamejin3', '【サッカー好きな】唯のゲーマー', 1, False],
#  ['TODDCastPodcast', 'Todd Hancock', 8421, False],
#  ['venugopalgali', 'Venu Gopal Gali', 5, False],
#  ['vivek_web', 'vivek pandey विवेक', 1312, False],
#  ['Jayanth17656566', 'Nomula Jayanth yadav', 29, False],
#  ['thebulletinbox', 'The Bulletin Box', 22, False],
#  ['ETNOWlive', 'ET NOW', 680680, True],
#  ['NIwJ5vwLxxtzrg7', '五輪生(iwao)', 81, False],
#  ['ct_latha', 'Latha CT', 6, False],
#  ['nitish_0087', 'nitish panwar', 0, False],
#  ['ApexFitzone', 'Apex FitZone', 7, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['sudheeshu', 'Sudheesh U', 130, False],
#  ['jeetbuzz', 'Jeetbuzz', 89, False],
#  ['Sateeshkumar965', 'Sathish Kumar', 3, False],
#  ['bharathkibeti', 'Devashree 🖤', 3092, False],
#  ['bharathkibeti', 'Devashree 🖤', 3092, False],
#  ['BradHast', 'Brad Hast', 479, False],
#  ['kokushokucom', '穀食.com（テレパシー情報屋）', 267, False],
#  ['kaguike', 'K.SoeTa（脱原発に一票）', 714, False],
#  ['morinosekai1414', 'なるみ👒期間限定🎐納涼アイコン(笑)🍧残暑お見舞い申し上げます🍉', 2271, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['FitEkaOc', 'bbyu(L)', 159, False],
#  ['6z_p1', 'ハルの子', 88, False],
#  ['tv9gujarati', 'tv9gujarati', 654116, True],
#  ['ZEE5News', 'ZEE5 News', 34143, True],
#  ['minervaowl_fly', 'Minerva owl', 2150, False],
#  ['8four25jr', '8four25', 146, False],
#  ['mezzobureaucrat', 'Jen J Harewood', 176, False],
#  ['Url4Ever', 'URL4EVER', 23, False],
#  ['narendra_garre', 'Garre Narendra', 177, False],
#  ['narendra_garre', 'Garre Narendra', 177, False],
#  ['FDNYWomen', 'FDNY Women', 2658, False],
#  ['2viciouzC', 'C3ViCiouZ', 16, False],
#  ['SweetCookiesme', 'Arvind', 624, False],
#  ['imAnkeshanand', '#Stay_Home #Stay_Safe 🇮🇳', 217, False],
#  ['Pamela84036781', 'Pamela', 20, False],
#  ['Tanya_Sinclair', 'Tanya Sinclair, CHRE 🇨🇦 🇯🇲', 326, False],
#  ['Corona_SSYT', 'Corona Virus Updates', 2586, False],
#  ['pchopner', 'Paulo Cesar Hopner🇧🇷🏴🐕🔰🌳🌲☘', 3307, False],
#  ['MacalusoJoseph', 'Joseph N Macaluso MD FACS', 1814, False],
#  ['LightspeedSteps', 'Lightspeed', 976, False],
#  ['AdamKarbowski', 'Adam Karbowski', 156, False],
#  ['LCoxMPH', 'Lisa Cox PR', 80, False],
#  ['Afterstorm13', 'Afterstorm', 1030, False],
#  ['SportBC', 'Sport BC', 6887, False],
#  ['41OPP', 'Seán Browne', 151, False],
#  ['jamiehansman', 'Jamie Hansman', 228, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['NicolaeCoj373', 'Nicolae Cojocaru', 2, False],
#  ['RobertLanex', 'Robert Lane', 1, False],
#  ['bissettfinfit', 'Tracey Bissett (she/her/hers)', 1299, False],
#  ['Dragofix', 'Dragofix', 4410, False],
#  ['sfischer2010', 'S Fischer', 8659, False],
#  ['sfischer2010', 'S Fischer', 8659, False],
#  ['TodoSports2021', 'Everything Sports', 154, False],
#  ['MimiSayani', 'Shershaah FTW', 1712, False],
#  ['ServerlessFan', 'Serverless Fan', 3687, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['pupijunkul', 'chris⁷ 🍀 | BEcause 🎠', 1270, False],
#  ['PoetOrganic', 'The Organic Poet', 1491, False],
#  ['Nasrull30828303', 'Nasrullah', 1845, False],
#  ['TheSugarMan__', 'ALPHA🧢H.V.M🐺📌', 7007, False],
#  ['Prepsyboard', 'Prepsy', 2, False],
#  ['WESmith91', 'William E. (Bill) Smith', 1024, False],
#  ['robynlisaflynn', 'Robyn Flynn', 5302, False],
#  ['Macaco30301', 'Macaco3030', 28, False],
#  ['CMFSC', 'Coquitlam Metro-Ford SC', 336, False],
#  ['AdeleScorpions', 'Adele Deakes', 581, False],
#  ['ServerlessFan', 'Serverless Fan', 3687, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['pmnorm', 'Dr. Woody/Carpenter Girl', 3222, False],
#  ['ServerlessFan', 'Serverless Fan', 3687, False],
#  ['BonjourKampala', 'Bonjour Kampala', 543, False],
#  ['VandanaThapa3', 'Vandana Thapa', 120, False],
#  ['goodeywrites', 'S. Goodey', 319, False],
#  ['__awitadeuwu__', 'Emilia PM', 25, False],
#  ['Alonso15922455', 'Alonso', 958, False],
#  ['dheeraj_miet', 'Dheeraj Verma', 96, False],
#  ['BaHARsanals', 'BaHARr ///___', 132, False],
#  ['Candelacata1', 'Candelacata1', 64, False],
#  ['miina0619', 'みいポリン☆', 73, False],
#  ['RealSamimAktar', 'Samim Aktar', 5308, False],
#  ['IrPsych', 'Carole (Ducky)', 4010, False],
#  ['NameeeeNice', 'Efua....❤️🇬🇭', 3683, False],
#  ['JijoTho85007776', 'Jijo Thomas', 3, False],
#  ['mycool015', 'ゆーき', 664, False],
#  ['JapanCons_vanc', '在バンクーバー日本国総領事館', 4291, True],
#  ['dn_rath', 'dn.rath@gmail.com', 482, False],
#  ['Wrestlingcardk1', 'Rob England', 606, False],
#  ['RumaRaj2', 'Ruma Raj', 1, False],
#  ['CHRISCERRONI', 'Chris Cerroni MSc', 597, False],
#  ['PwH4Iut68HeW4GX', 'زهراء العلي', 709, False],
#  ['ano_ha', 'あのはな', 54, False],
#  ['anandkhatod8', 'आनंदकुमार खटोड', 26, False],
#  ['RamireddyBommi1', 'Ramireddy Bommireddy', 84, False],
#  ['virajsw', 'Viraj suwasiya', 13, False],
#  ['tphfamily', 'TPH', 273, False],
#  ['Keremela12', 'Keremela', 0, False],
#  ['garbett_stephen', 'Stephen Garbett', 629, True],
#  ['HariomVhp', 'हरिओम राजावत विहिप #प्रशासक_समिति', 1806, False],
#  ['casanor11', 'NatteramnGjenferd', 538, False],
#  ['masoom_anw', 'Masoom Anwar', 2, False],
#  ['GsLessons', 'DrGsHistoryLessons', 14, False],
#  ['Anurag73916381', 'Anurag', 13, False],
#  ['aepedia', '🅰️3️⃣🅿️🇵🇱🇵🇸', 70, False],
#  ['efbman', '🇮🇪 Éanna 🐾🇪🇺🇵🇸🏳️\u200d🌈🥊🏉⚽️', 1572, False],
#  ['jules878', 'Julia Palmer', 349, False],
#  ['NLIreland', 'National Library of Ireland', 42034, False],
#  ['livingstonfinan', 'Peter Livingston', 1474, False],
#  ['FGM166', 'Faisal', 152, False],
#  ['Rimjhimsen12', 'Rimjhim sen', 6, False],
#  ['juliebabyar', 'Julie Babyar', 9705, False],
#  ['janbarstad', 'janbarstad', 6664, False],
#  ['PANKAJT1001', 'PANKAJ THAKARE', 60, False],
#  ['hemanth1981998', 'Hém@ñțh', 591, False],
#  ['duxfemfac', "La'Tasha D. Mayes", 2966, False],
#  ['thenewshooked', 'TheNewsHOOK', 1276, False],
#  ['bcsoccerweb', 'BCSoccerWeb.com', 2402, False],
#  ['PradeepYdv20', 'Pradeep yadav', 2102, False],
#  ['juliebabyar', 'Julie Babyar', 9705, False],
#  ['AryaGow24804227', 'Arya Gowda', 0, False],
#  ['BoldProfitDaily', 'Bold Profits Daily', 3249, False],
#  ['amitshah_MH09', '🇮🇳 Amit Shah, Kolhapur, Bharat 🇮🇳', 394, False],
#  ['DasiKrsna', 'Lipsa (krsna Dasi)', 420, False],
#  ['DevDasRathore1', 'Dev Das (SHERSHAAH)', 199, False],
#  ['ponsharan', 'Pon Saravanan', 227, False],
#  ['Amalia13325296', 'Amalia', 31, False],
#  ['girija_achary', 'Girija Acharya', 53, False],
#  ['shaunwillo90', 'Shaun Williams', 423, False],
#  ['mikemeidling', 'Mike M.', 935, False],
#  ['MMAFighting', 'MMAFighting.com', 616966, True],
#  ['Creaform', 'Creaform', 3447, False],
#  ['shyam_kit', 'shyam', 20, False],
#  ['Barketalikhan41', 'Barketalikhan4589@gmail.Com', 5, False],
#  ['ABHINAV53292443', 'ABHINAV JHA', 53, False],
#  ['TechnoFails', 'Anykey', 9365, False],
#  ['TigerManjeet1', 'Tiger Manjeet', 0, False],
#  ['nandhu1512', 'Nandhakumar', 305, False],
#  ['SunilDravidan', 'Sunil Dravidan (திராவிடன்)', 1014, False],
#  ['sharonlinapearc', 'Sharon Lina Pearce', 989, False],
#  ['SekharB76486652', 'Sekhar Biswas', 42, False],
#  ['abdsamad', 'abdussamad', 67, False],
#  ['Rkchaupal2004', 'Ramdhari kumar', 1, False],
#  ['orlando300121', 'orlando matsota', 3, False],
#  ['alvinfoo', 'Alvin Foo', 71940, False],
#  ['1BCSoccer', 'BC Soccer', 6631, False],
#  ['ConesPinniespod', 'Cones&PinniesPod', 118, False],
#  ['Adamson63309869', 'Adamsons', 715, False],
#  ['carleton_douse', 'carleton douse', 14, False],
#  ['enterskills_i', 'Desiré Mutumba', 2305, False],
#  ['shasiri17', 'Shirisha', 81, False],
#  ['DharmaT45762805', 'Dharma Teja', 51, False],
#  ['GemsDawson', 'Gemma Dawson', 3540, False],
#  ['SMKN7Ska', 'Official account SMK N 7 Surakarta', 136, False],
#  ['johnekennett', 'John E. Kennett', 341, False],
#  ['alvinfoo', 'Alvin Foo', 71940, False],
#  ['ghssorg', 'Green Heart Springs', 27, False],
#  ['AbdoulR37230833', 'Abdoul Razack Karimou Ousmane', 538, False],
#  ['Yashkrizz', 'Yash', 792, False],
#  ['Yashkrizz', 'Yash', 792, False],
#  ['Yashkrizz', 'Yash', 792, False],
#  ['Yashkrizz', 'Yash', 792, False],
#  ['AshrafAliSyed3', 'ASHRAF YSRCP', 8, False],
#  ['nagar_jha', 'Nishant Nagar Jha', 8, False],
#  ['WestphalErin', 'Erin Westphal', 497, False],
#  ['RajowarAnimesh', 'ANIMESH RAJOWAR', 0, False],
#  ['Jing85919405', 'Jing', 56, False],
#  ['Praveen74833933', 'Praveen Kumar', 75, False],
#  ['AjeethK40221698', 'Ajeeth Kumar', 18, False],
#  ['flerlagekr', 'Ken Flerlage', 9660, False],
#  ['Chintan35610572', 'Chintan Thakor', 6, False],
#  ['Schreids', 'Michaela Schreiter', 3416, False],
#  ['Malamute_Dad', "Budzo's Dad 🌍🌲🏳️\u200d🌈🇺🇸", 124, False],
#  ['ManiacBridge', 'Bridge Maniac', 536, False],
#  ['emefen_', '.E M E F E N.', 452, False],
#  ['Back_in_Action', 'Dr Ian Horsley', 9149, False],
#  ['Rohit00484461', 'रोहित 🕉️🚩', 1230, False],
#  ['WestphalErin', 'Erin Westphal', 497, False],
#  ['WestphalErin', 'Erin Westphal', 497, False],
#  ['robynlisaflynn', 'Robyn Flynn', 5302, False],
#  ['aerezona', 'کپتان کا سپاہی', 250, False],
#  ['THEFREEMEDIA2K', 'THE FREE MEDIA', 58, False],
#  ['josephfelix210', 'Joseph Felix', 329, False],
#  ['pdpsingha', 'Pradeep', 1228, False],
#  ['KumarNavakumar', 'Navakumar Kumar Rabha', 0, False],
#  ['asancetta', 'Amy Sancetta', 930, True],
#  ['_Sai_Turlapati_', '__Sai Turlapati__', 19, False],
#  ['Gowtham09941970', 'Gowtham', 3, False],
#  ['Paaruu88', 'Itz_paaruu_88', 0, False],
#  ['Opoyis', 'Opoyi', 11375, False],
#  ['JigyanshuPande5', 'Jigyanshu Pandey', 14, False],
#  ['JGeeEleven', 'JGee', 17, False],
#  ['IvettAlexa', 'Kovács Ivett', 2931, False],
#  ['fernanadez99', 'Daniel John', 11, False],
#  ['paavan_anakin', 'Paavan', 67, False],
#  ['shamindraghosh1', 'shamindra ghosh', 30, False],
#  ['iamYugal18', 'Yugal Chambhare🇮🇳', 481, False],
#  ['AppleReddy7', 'sandhyareddy', 8, False],
#  ['the_hindu', 'The Hindu', 7130707, True],
#  ['TheHinduSports', 'The Hindu - Sports', 48017, True],
#  ['Khushbo46652613', 'Khush💥', 278, False],
#  ['tutuhead4', 'Michael Smith', 147, False],
#  ['sportpsychmind', 'Dr. Chelsi Day', 1864, False],
#  ['PeteOlusoga', 'Dr Peter Olusoga', 14555, False],
#  ['EPMPodcast', 'EightyPercentMental', 1928, False],
#  ['IsaacCopenhave3', 'El Potato', 296, False],
#  ['hiroko_7788', 'Hiro REDTaylorsVersion 🧣', 21854, False],
#  ['sangi_91', 'Sadanand patel', 7, False],
#  ['MohitKu45550608', 'Mohit Kumar', 7, False],
#  ['Sachibiswal092', 'Sachidananda Biswal', 9, False],
#  ['SDebasisIndian', 'S Debasis', 38, False],
#  ['thecovidsite', 'COVID News', 3295, False],
#  ['KyleOlbert', 'K. Olbert', 15840, False],
#  ['SmartDhyana', 'Dhyana', 121, False],
#  ['NamanAr22280575', 'Er. Naman Arora🇮🇳', 84, False],
#  ['garsampath', 'G.A.R. Sampath', 117, False],
#  ['vnzyrtx', 'nca', 39, False],
#  ['whatrtheoptions', 'Lindsey Galley', 33, False],
#  ['CSomnianti', 'CaveatSomnianti', 135, False],
#  ['RashmiV31194895', 'Rashmi Verma', 17, False],
#  ['sallypenni1', 'Sally Penni MBE🐝🐝 (She/Her)', 5145, False],
#  ['ImtiazGul60', 'Imtiaz Gul', 63119, False],
#  ['maybenadi02', 'Nadi 🦋', 31847, False],
#  ['AKNarne', 'అమరావతి; విశాఖ ఉక్కు - ఆంధ్రుల హక్కు 💪', 2605, False],
#  ['befriendings', 'Clive Lawrinson', 2170, False],
#  ['prakash_aravind',
#   'Prakash N- Sports Lover & follower from Namakkal',
#   213,
#   False],
#  ['AnilGou53184667', 'AniL_GoUd', 1, False],
#  ['das_sharu', 'Sharu Das', 2014, False],
#  ['SeithHasnainali', 'Hasnain Ali', 48, False],
#  ['iMiFpgC0xz4hGdj', 'ኤረትራ ዋጋ ስዉእ,ያ', 20, False],
#  ['itschandany', 'CHANDAN', 490, False],
#  ['KeBillion', 'Missionary ♀️', 842, False],
#  ['teachedison', 'TeachEdison', 125, False],
#  ['theedisonos', 'EdisonOS', 14, False],
#  ['DevoteeYs', 'Ys Jagan Devotee', 1, False],
#  ['neeraj_choyal', 'Neeraj Choyal', 31, False],
#  ['RatnakarKrishn1', 'Ratnakar', 411, False],
#  ['AkashMk24520486', 'Akash Mk', 7, False],
#  ['AyuTriwn', 'pengabdiwifi', 846, False],
#  ['missartola', 'smita mishra 🇮🇳', 5366, False],
#  ['crownchronicles', 'The Crown Chronicles', 9771, False],
#  ['CricGorgeous', 'Mahi', 153, False],
#  ['BotMobilegame', 'Mobile Game Bot', 424, False],
#  ['KishanMaiyad', 'KRUSHNAM', 46, False],
#  ['MyLife_Congress', 'I Am Being Human 💕🖐💕', 3528, False],
#  ['PavanKu19517349', 'PAVAN KUMAR PRAJAPTI', 9, False],
#  ['chomsessentials', 'Chomsessentials', 57, False],
#  ['RFYouthSports', 'RF Youth Sports', 4919, True],
#  ['Nitish84984891', 'Nitish', 4, False],
#  ['velvetangels17', 'Sofia⁷≷ (fan.acc)🥰💫🍒⚾️🏐🏸', 839, False],
#  ['SalemDinesh12', 'Salem Dinesh', 4, False],
#  ['JustAsk46082871', 'Just Asking', 41, False],
#  ['GtwoRath', 'Jitu', 233, False],
#  ['donaldhussle', 'Donaldhussle', 858, False],
#  ['ccitraandini', 'Citra Andini 🌙✨', 156, False],
#  ['GulrezShagufa', 'Shagufa Khan', 20, False],
#  ['Khanji61685240', 'Khanji', 1393, False],
#  ['MitraDebu1', 'MitraDebu', 23, False],
#  ['indianposten', 'indianposten', 460, False],
#  ['ABKPE', 'Alderbrook School PE', 261, False],
#  ['ThePEpodcast_', 'The PE Podcast', 66, False],
#  ['HaeSoo23', 'Hae Soo', 249, False],
#  ['hi_dstaeri', 'ᮓᮨᮞ᮪ᮒᮢᮤ', 264, False],
#  ['Andriyan_syahh', 'Andriyansyah Unan', 717, False],
#  ['Rahul90431108', 'Rahul', 51, False],
#  ['BlackArrowsBC', 'Black Arrows', 263, False],
#  ['thebulletinbox', 'The Bulletin Box', 22, False],
#  ['BickyDa96697382', 'Bicky Das', 19, False],
#  ['YordaBerhane', 'Yordanos', 15, False],
#  ['eeraavihcvb', 'Crystal', 4, False],
#  ['Crystaltuner', 'Krystal Bea', 340, False],
#  ['Crystaltuner', 'Krystal Bea', 340, False],
#  ['kachave_ashwini', 'ashwini kachave', 1, False],
#  ['nadhirahmania', 'Nadh 🐧🐰', 269, False],
#  ['VIVEKSINGHANIA2', 'VIVEK SINGHANIA', 1962, False],
#  ['KRISYNR', 'KRISHAN KUMAR', 5, False],
#  ['moulanapanji', 'Panji Moulana', 538, False],
#  ['Son_of_Soil123', 'From_the_soul', 60, False],
#  ['CNBCTV18News', 'CNBC-TV18', 956792, True],
#  ['BiIndia', 'Business Insider India🇮🇳', 110775, True],
#  ['bludgerwood', 'ً', 148, False],
#  ['_minjeong_j4f',
#   '👀Minjeong là nhân viên của JinHit Entertainment👀',
#   1226,
#   False],
#  ['Akk10342145', 'Akk', 2, False],
#  ['IsmiMaulidyati', 'イスミ', 1574, False],
#  ['rdsoprince', 'PRINCE KUMAR', 1092, False],
#  ['rdsoprince', 'PRINCE KUMAR', 1092, False],
#  ['MazumderShital', 'Shital Mazumder', 14, False],
#  ['imRohit__', 'Rohit  Rajput', 5, False],
#  ['SwissCognitive', 'SwissCognitive – The Global AI Hub', 138738, False],
#  ['deer668745381', 'deer66874538', 902, False],
#  ['asyiq23', 'M. Asyiq Khoiril Anam', 216, False],
#  ['IsmiMaulidyati', 'イスミ', 1574, False],
#  ['JasrotiaChander', 'Chander Jasrotia', 5, False],
#  ['SarathKallepal1', 'sarath..!!', 25, False],
#  ['longestrally', '🥇🥉', 106, False],
#  ['ShreyVerdhan', 'Shrey Verdhan Pandey', 41, False],
#  ['sarcasmisttt', 'many moods', 1, False],
#  ['AGohuleshwar', 'Gohuleshwar.A ( Wear a Mask )', 974, False],
#  ['Deepu35729654', 'Deepu', 81, False],
#  ['Surabhi85711617', 'Surabhi Yadav', 87, False],
#  ['eka_aditya33', 'PengAMAT AMATiran', 314, False],
#  ['suri4akhil', 'suriforjagan', 376, False],
#  ['AayushG50829689', 'Aayush Goyal', 32, False],
#  ['RavirajSujatha', 'Suja Raviraj', 15, False],
#  ['EntrepreneurIND', '@EntrepreneurInd', 27984, True],
#  ['EURACTIV', 'EURACTIV', 138427, True],
#  ['CupidAutosNG', 'CUPID AUTOS NG', 2580, False],
#  ['Kuldeep92974795', 'Kuldeep Singh', 20, False],
#  ['Rosiedem1', 'Rosiedem', 5, False],
#  ['NextGen1992', 'Kinza', 1682, False],
#  ['Prashan09593784', 'Prashant koli', 34, False],
#  ['JeetSin82301407', 'जीत सिंह #indiatogether', 549, False],
#  ['iUzmaHTahir', 'Uzma 👠', 3449, False],
#  ['lokeshluniwal1', 'lokeshluniwal', 8, False],
#  ['Brijendragupt22', 'Brijendra gupta', 112, False],
#  ['Anshulrajput604', 'Anshul Rajput', 16, False],
#  ['chessmatica', 'Chessmatica', 230, False],
#  ['SubhashBesra66', 'Subhash Besra', 0, False],
#  ['TinoKottia', 'ᴮᴱVirgil Kottia⁷', 105, False],
#  ['Janidipak_', 'Jani Dipak', 73, False],
#  ['Ankita77109321', 'MODI, YOGI & AMIT JI. FANS🇮🇳❤', 10, False],
#  ['hilton_philip', 'Philip Hilton yogi main', 3666, False],
#  ['dungachoud6', 'Aanjana Dungar', 7024, False],
#  ['sriniva97224608', 'srinivasa raju', 1, False],
#  ['lunatic_speaks', 'Lunatic Speaks', 1, False],
#  ['wearegirlsinsp1', '@wearegirlsinsport', 476, False],
#  ['dearvenkatesh', '🕊VenkateshVanapalli 🥰💛❤️', 1, False],
#  ['CNBCTV18News', 'CNBC-TV18', 956792, True],
#  ['Prince61681112', 'ambivert', 50, False],
#  ['DhruvDeepak6', 'Dhruv Deepak', 109, False],
#  ['LeidenHum', 'Leiden University - Faculty of Humanities', 7637, False],
#  ['PratikJ54547351', 'Pratik Jagtap', 0, False],
#  ['09Dheeraj', 'Dheeraj', 42, False],
#  ['NeerajS72241811', 'Neeraj Singh', 61, False],
#  ['NewsOfTheDayin', 'News Of The Day -2021', 17, False],
#  ['Roma76451299', 'RomaaG', 7, False],
#  ['VaibhavPrakas19', 'Vaibhav', 73, False],
#  ['BakersValley', 'I Support Baba Ramdev 🇮🇳 Goodridge Easyday', 641, False],
#  ['nanda_sitansu', 'Dr. Sitansu S. Nanda', 324, False],
#  ['MayaSah48845014', 'isha sahu', 7, False],
#  ['IamRohan2468', 'IAM ROHAN', 12, False],
#  ['DeepakKumar452', 'Deepak Kumar', 11, False],
#  ['Aman80350587', 'Aman', 72, False],
#  ['janmesinuraya', 'jamesames', 971, False],
#  ['fluffykangbri', 'yol ☾', 151, False],
#  ['Badal54529147', 'Badal', 1, False],
#  ['impawansahu', 'Pawan Sahu', 371, False],
#  ['Maruthi_mrm', 'Maruthi', 282, False],
#  ['LehrenNetworks', 'Lehren', 7055, False],
#  ['emwatsonmyqueen', '#Mahakali', 362, False],
#  ['TheN8king', '🌞', 98, False],
#  ['nehakhanna_07', 'Neha Khanna', 4892, False],
#  ['AkshayR35765713', 'Akshay Raghuvanshi', 0, False],
#  ['DeepakBarola', 'Deepak Barola 100%follow Back', 482, False],
#  ['nehakhanna_07', 'Neha Khanna', 4892, False],
#  ['Sakthiv90068247', 'thalapathy', 61, False],
#  ['1_White_Ranger', 'The White Ranger⚡️', 77, False],
#  ['NithinG70786121', 'Nithin Goud', 29, False],
#  ['Anupkum84665117', 'Anupkumar Singh', 0, False],
#  ['Prasad43017528', 'yoursPrassuuu', 1, False],
#  ['RaviSin29896987', 'Ravi Singh', 2, False],
#  ['praya8hkumar', 'Prayash Kumar', 24, False],
#  ['Mohapat29779450', 'Mohapatra', 11, False],
#  ['CnpavanK', 'CNPavan Kumar', 9, False],
#  ['shychwng', 'ÃlwáyßSychwng', 19, False],
#  ['Dj92475914', 'Dj', 64, False],
#  ['MISHRA1097', '🇮🇳 पंडित जीवेश मिश्रा 🇮🇳', 109, False],
#  ['ellaxlouise1', '☔🦊🏀📖nagiisip ng?', 1381, False],
#  ['pratik901', 'Pratik Shah', 104, False],
#  ['smallypaula',
#   'Smally #NHSLove 💙 Fibromyalgia #Barrett’s #TDC..',
#   831,
#   False],
#  ['GBRWrestlingNGB', 'British Wrestling 🤼🤼\u200d♀️', 887, False],
#  ['Pobbathi_Venku', 'Venkateswarlu P🇮🇳', 749, False],
#  ['Ramkuma37107733', '💜𝙍𝙖𝙢💜', 145, False],
#  ['Praveen08367523', 'Praveen Kumar', 3, False],
#  ['Ebrahimbadu', 'Ebrahim badusha', 451, False],
#  ['Ebrahimbadu', 'Ebrahim badusha', 451, False],
#  ['Navi1Kamboj', 'NAVDEEP KUMAR', 16, False],
#  ['Jyo88845553', 'Jyo DHFM..🔔', 20, False],
#  ['Sik_And_Er', 'S̸i̸k̸a̸n̸d̸e̸r̸ S̸i̸n̸g̸h̸', 49, False],
#  ['SudhaMi20274124', 'Sudha Mishra', 27, False],
#  ['ghall27', 'Gareth Hall', 8342, False],
#  ['hemakini', 'Hemalatha', 3767, False],
#  ['eixquisitely', 'r/', 33, False],
#  ['KushwantSai', 'stanhunksaik2', 416, False],
#  ['parpandicular', 'Gajendra Chouhan', 6, False],
#  ['MEHULKU85993531', 'MEHUL KUMAR 🇮🇳', 12, False],
#  ['nitin_sharma76', 'NITIN SHARMA', 181, False],
#  ['warriorarjunnn', '🐅 Justice For Vishal Zood', 567, False],
#  ['Humourously_S', 'humourously_sarcastic', 79, False],
#  ['Hemantr241116', 'Hemant rai', 188, False],
#  ['FIJI7sRugby', 'FIJI 7s Rugby', 1414, False],
#  ['RudhitaF', 'Rudhita_', 474, False],
#  ['shokethepally', 'SHOKETHEPALLY', 346, False],
#  ['_V_I_N_O_T_H_DX', 'ThalapathyVinoth', 24, False],
#  ['Dinesh84663853', 'Dinesh Choudhary', 25, False],
#  ['PALAKKHARE9', 'PALAK KHARE 🇮🇳with🇮🇱always', 10, False],
#  ['indalwai_ps', 'SHO_Indalwai_PS', 54, False],
#  ['MahipalRanawat1', 'Mahipal Ranawat', 17, False],
#  ['f__setyawan', 'fani aan setyawan', 218, False],
#  ['siddka', 'Siddharth Jain', 58, False],
#  ['brobbeer', 'retweeter🇮🇳', 128, False],
#  ['MahathaRishav', '🇮🇳Rishav Mahatha', 103, False],
#  ['eightbridges_88', 'Tsunex', 481, False]]

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
schema = StructType([ \
    StructField("Username",StringType(),True), \
    StructField("Name",StringType(),True), \
    StructField("Followers_count", IntegerType(), True), \
    StructField("Verified", StringType(), True) \
  ])
 
df = spark.createDataFrame(data=users_details,schema=schema)
#df.printSchema()
#df.show(truncate=False)
df.where(df.Verified == "true").show()
# Out:
# +---------------+----------------------------+---------------+--------+
# |       Username|                        Name|Followers_count|Verified|
# +---------------+----------------------------+---------------+--------+
# |BangaloreTimes1|             Bangalore Times|         159755|    true|
# |       HydTimes|             Hyderabad Times|          57176|    true|
# |       bwfmedia|                         BWF|         196780|    true|
# |DelhiTimesTweet|                 Delhi Times|          77812|    true|
# |      PIBMumbai|        PIB in Maharashtr...|          58955|    true|
# |      ETNOWlive|                      ET NOW|         680680|    true|
# |    tv9gujarati|                 tv9gujarati|         654116|    true|
# |       ZEE5News|                   ZEE5 News|          34143|    true|
# | JapanCons_vanc|在バンクーバー日本国総領事館|           4291|    true|
# |garbett_stephen|             Stephen Garbett|            629|    true|
# |    MMAFighting|             MMAFighting.com|         616966|    true|
# |      asancetta|                Amy Sancetta|            930|    true|
# |      the_hindu|                   The Hindu|        7130707|    true|
# | TheHinduSports|          The Hindu - Sports|          48017|    true|
# |  RFYouthSports|             RF Youth Sports|           4919|    true|
# |   CNBCTV18News|                   CNBC-TV18|         956792|    true|
# |        BiIndia|        Business Insider ...|         110775|    true|
# |EntrepreneurIND|            @EntrepreneurInd|          27984|    true|
# |       EURACTIV|                    EURACTIV|         138427|    true|
# |   CNBCTV18News|                   CNBC-TV18|         956792|    true|
# +---------------+----------------------------+---------------+--------+
